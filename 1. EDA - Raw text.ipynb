# %%
import os

path, dirs, files = next(os.walk("data/raw"))
file_count = len(files)
file_count
# Out:
# 583

# %%
from pathlib import Path

p = Path("data/raw")
p.glob('**/*')
# Out:
# <generator object Path.glob at 0x7f1291f625f0>

# %%
path, dirs, files = next(os.walk("data/processed-nico"))
file_count = len(files)
file_count
# Out:
# 583

# %%
files
# Out:
# ['SW012512.txt',
#  'SW010912.txt',
#  'SP0107P3.txt',
#  'SP0128P1.txt',
#  'JP012812.txt',
#  'SW0117P3.txt',
#  'SW0145P2.txt',
#  'SW0139P2.txt',
#  'SW0136P1.txt',
#  'SW013012.txt',
#  'SP0135P1.txt',
#  'SW0101P2.txt',
#  'SW0109P3.txt',
#  'JP0139P1.txt',
#  'JP012012.txt',
#  'SP0113P1.txt',
#  'SW011112.txt',
#  'JP0119P2.txt',
#  'SP0142P2.txt',
#  'JP0137P1.txt',
#  'SP0116P3.txt',
#  'SP010412.txt',
#  'JP0129P2.txt',
#  'SP010712.txt',
#  'JP0138P2.txt',
#  'SP0109P2.txt',
#  'JP0135P2.txt',
#  'SP0118P1.txt',
#  'SP0143P3.txt',
#  'JP0134P3.txt',
#  'SP0143P2.txt',
#  'SW011212.txt',
#  'JP0105P2.txt',
#  'SP0140P2.txt',
#  'SP0102P2.txt',
#  'JP0142P1.txt',
#  'SP0125P2.txt',
#  'SW010312.txt',
#  'JP0113P2.txt',
#  'JP0103P1.txt',
#  'SP0111P2.txt',
#  'JP014612.txt',
#  'SP0139P1.txt',
#  'SW0125P1.txt',
#  'SP0129P3.txt',
#  'JP010512.txt',
#  'SP0101P2.txt',
#  'JP014812.txt',
#  'JP010312.txt',
#  'SW0126P1.txt',
#  'JP014412.txt',
#  'SP0144P3.txt',
# ...

# %%
set([f[:2] for f in files])
# Out:
# {'JP', 'SP', 'SW'}

# %%
set([f[-6:] for f in files])
# Out:
# {'12.txt', 'P1.txt', 'P2.txt', 'P3.txt'}

# %%
print("JP:", sum('JP' in s for s in files))
print("SW:", sum('SW' in s for s in files))
print("SP:", sum('SP' in s for s in files))
# Out:
# JP: 202
# SW: 200
# SP: 181

# %%
print("P1:", sum('P1.t' in s for s in files))
print("P2:", sum('P2.t' in s for s in files))
print("P3:", sum('P3.t' in s for s in files))
print("12:", sum('12.t' in s for s in files))
# Out:
# P1: 148
# P2: 144
# P3: 148
# 12: 143
